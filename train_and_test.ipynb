# %% [markdown]
# ## Reference: https://github.com/WuJie1010/Facial-Expression-Recognition.Pytorch

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/Colab Notebooks/csc420_bacloud"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/csc420_bacloud

# %%
# !python preprocess_fer2013.py

# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torchvision
import transforms as transforms
import numpy as np
import os

from torch.autograd import Variable

# import argparse
import utils
# dataclass
from fer import FER2013
# model declarations
from models import *

# %%
class Opt():
  def __init__(self):
    self.model = "Xception"
    self.dataset = "FER2013"
    self.bs = 128
    self.lr = .01
  
  def __str__(self):
    return f"model = {self.model}\ndataset = {self.dataset}\nbatchsize = {self.bs}\nlearning rate = {self.lr}"

opt = Opt()
print(opt)
# Out:
# model = Xception
# dataset = FER2013
# batchsize = 128
# learning rate = 0.01

# %%
# params
use_cuda = torch.cuda.is_available()
print("training on CPU" if not use_cuda else "GPU in place!")

best_validation_acc = 0  # best validation accuracy
best_validation_acc_epoch = 0
best_test_acc = 0  # best test accuracy
best_test_acc_epoch = 0

learning_rate_decay_start = 40  # 50
learning_rate_decay_every = 5 # 5
learning_rate_decay_rate = 0.9 # 0.9

cut_size = 44
total_epoch = 250

path = os.path.join(opt.dataset + '_' + opt.model)
print(f"savepath is {path}")
# Out:
# GPU in place!
# savepath is FER2013_Xception

# %%
# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(cut_size),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.TenCrop(cut_size),
    transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
])

trainset = FER2013(split = 'Training', transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=opt.bs, shuffle=True, num_workers=1)
validationset = FER2013(split = 'validation', transform=transform_test)
validationloader = torch.utils.data.DataLoader(validationset, batch_size=opt.bs, shuffle=False, num_workers=1)
testset = FER2013(split = 'test', transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=opt.bs, shuffle=False, num_workers=1)
# Out:
# ==> Preparing data..

# %%
# Model

if opt.model  == 'Resnet18':
    net = ResNet18()
elif opt.model == 'Xception':
    net = Xception(input_channel=3)
elif opt.model.startswith('VGG'):
    net = VGG(opt.model)

print(f'==> Building model {opt.model}..')

if use_cuda:
    net.cuda()

criterion = nn.CrossEntropyLoss()
# SGD could be more generalizable but it is slower in convergence
# weight decay option adds regularization. 
optimizer = optim.SGD(net.parameters(), lr=opt.lr, momentum=.9, weight_decay=5e-4)
# optimizer = optim.Adam(net.parameters(), lr=opt.lr, weight_decay=5e-4)
# Out:
# ==> Building model Xception..

# %%
# Training
def train(epoch):
    print('\n---\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    if epoch > learning_rate_decay_start and learning_rate_decay_start >= 0:
        frac = (epoch - learning_rate_decay_start) // learning_rate_decay_every
        decay_factor = learning_rate_decay_rate ** frac
        current_lr = opt.lr * decay_factor
        utils.set_lr(optimizer, current_lr)  # set the decayed rate
    else:
        current_lr = opt.lr
    print('learning_rate: %s' % str(current_lr))

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()
        optimizer.zero_grad()
        inputs, targets = Variable(inputs), Variable(targets)
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        utils.clip_gradient(optimizer, 0.1)
        optimizer.step()
        train_loss += loss.data
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()

        # for command line
        # utils.progress_bar(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
        #     % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))

    Train_acc = 100.*correct/total
    print(f"Trainning Accuracy: {Train_acc:.10f}")

# %%
def validation(epoch):
    global validation_acc
    global best_validation_acc
    global best_validation_acc_epoch
    net.eval()
    validation_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(validationloader):
        bs, ncrops, c, h, w = np.shape(inputs)
        inputs = inputs.view(-1, c, h, w)
        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()
        with torch.no_grad():
          # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
          outputs = net(inputs)
          outputs_avg = outputs.view(bs, ncrops, -1).mean(1)  # avg over crops
          loss = criterion(outputs_avg, targets)
          validation_loss += loss.data
          _, predicted = torch.max(outputs_avg.data, 1)
          total += targets.size(0)
          correct += predicted.eq(targets.data).cpu().sum()

          # for command line
          # utils.progress_bar(batch_idx, len(validationloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
          #                   % (validation_loss / (batch_idx + 1), 100. * correct / total, correct, total))

    # Save checkpoint.
    validation_acc = 100.*correct/total
    print("validation_acc: %0.3f" % validation_acc)
    if validation_acc > best_validation_acc:
        print('Saving..')
        print("best_validation_acc: %0.3f" % validation_acc)
        
        state = {
            'net': net.state_dict() if use_cuda else net,
            'acc': validation_acc,
            'epoch': epoch,
        }
        if not os.path.isdir(path):
            os.mkdir(path)
        torch.save(state, os.path.join(path,'validation_model.t7'))
        best_validation_acc = validation_acc
        best_validation_acc_epoch = epoch

# %%
# deprecated, we will be keeping test set only for the best validation model
def test(epoch):
    global test_acc
    global best_test_acc
    global best_test_acc_epoch
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(testloader):
        bs, ncrops, c, h, w = np.shape(inputs)
        inputs = inputs.view(-1, c, h, w)
        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()
        with torch.no_grad():
          # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
          outputs = net(inputs)
          outputs_avg = outputs.view(bs, ncrops, -1).mean(1)  # avg over crops
          loss = criterion(outputs_avg, targets)
          test_loss += loss.data
          _, predicted = torch.max(outputs_avg.data, 1)
          total += targets.size(0)
          correct += predicted.eq(targets.data).cpu().sum()

          utils.progress_bar(batch_idx, len(validationloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
              % (test_loss / (batch_idx + 1), 100. * correct / total, correct, total))
    # Save checkpoint.
    test_acc = 100.*correct/total

    if test_acc > best_test_acc:
        print('Saving..')
        print("best_test_acc: %0.3f" % max(test_acc, best_test_acc))
        state = {
            'net': net.state_dict() if use_cuda else net,
            'best_validation_acc': best_validation_acc,
            'best_test_acc': test_acc,
            'best_validation_acc_epoch': best_validation_acc_epoch,
            'best_test_acc_epoch': epoch,
        }
        if not os.path.isdir(path):
            os.mkdir(path)
        torch.save(state, os.path.join(path,'test_model.t7'))
        best_test_acc = test_acc
        best_test_acc_epoch = epoch

# %%
print(opt)

# training loop
for epoch in range(total_epoch):
    train(epoch)
    validation(epoch)
    # test(epoch)

print("best_validation_acc: %0.3f" % best_validation_acc)
print("best_validation_acc_epoch: %d" % best_validation_acc_epoch)
# print("best_test_acc: %0.3f" % best_test_acc)
# print("best_test_acc_epoch: %d" % best_test_acc_epoch)
# Out:
# ---
# Epoch: 0
# learning_rate: 0.01
# Trainning Accuracy: 34.5989074707
# validation_acc: 32.042
# Saving..
# best_validation_acc: 32.042
#
# ---
# Epoch: 1
# learning_rate: 0.01
# Trainning Accuracy: 46.4592971802
# validation_acc: 36.890
# Saving..
# best_validation_acc: 36.890
#
# ---
# Epoch: 2
# learning_rate: 0.01
# Trainning Accuracy: 51.5099792480
# validation_acc: 41.906
# Saving..
# best_validation_acc: 41.906
#
# ---
# Epoch: 3
# learning_rate: 0.01
# Trainning Accuracy: 54.8573608398
# validation_acc: 41.098
#
# ---
# Epoch: 4
# learning_rate: 0.01
# Trainning Accuracy: 57.0378608704
# validation_acc: 43.689
# Saving..
# best_validation_acc: 43.689
#
# ---
# Epoch: 5
# learning_rate: 0.01
# Trainning Accuracy: 58.2918243408
# validation_acc: 38.339
#
# ---
# Epoch: 6
# learning_rate: 0.01
# Trainning Accuracy: 59.8383789062
# validation_acc: 37.838
#
# ---
# Epoch: 7
# learning_rate: 0.01
# Trainning Accuracy: 61.1445884705
# validation_acc: 27.974
#
# ---
# Epoch: 8
# learning_rate: 0.01
# Trainning Accuracy: 62.2766380310
# validation_acc: 43.633
#
# ---
# Epoch: 9
# learning_rate: 0.01
# Trainning Accuracy: 63.1439628601
# validation_acc: 35.135
#
# ---
# Epoch: 10
# learning_rate: 0.01
# Trainning Accuracy: 64.1366806030
# validation_acc: 43.801
# Saving..
# best_validation_acc: 43.801
#
# ---
# Epoch: 11
# learning_rate: 0.01
# Trainning Accuracy: 65.0353546143
# validation_acc: 36.361
#
# ---
# Epoch: 12
# learning_rate: 0.01
# Trainning Accuracy: 65.8330154419
# validation_acc: 44.748
# Saving..
# best_validation_acc: 44.748
#
# ---
# Epoch: 13
# learning_rate: 0.01
# Trainning Accuracy: 66.9093322754
# validation_acc: 45.110
# Saving..
# best_validation_acc: 45.110
#
# ---
# Epoch: 14
# learning_rate: 0.01
# Trainning Accuracy: 67.4596786499
# validation_acc: 43.020
#
# ---
# Epoch: 15
# learning_rate: 0.01
# Trainning Accuracy: 68.5708312988
# validation_acc: 42.797
#
# ---
# Epoch: 16
# learning_rate: 0.01
# Trainning Accuracy: 69.1037673950
# validation_acc: 35.776
#
# ---
# Epoch: 17
# learning_rate: 0.01
# Trainning Accuracy: 69.5496215820
# validation_acc: 50.320
# Saving..
# best_validation_acc: 50.320
#
# ---
# Epoch: 18
# learning_rate: 0.01
# Trainning Accuracy: 70.1243515015
# validation_acc: 47.451
#
# ---
# Epoch: 19
# learning_rate: 0.01
# Trainning Accuracy: 71.0056076050
# validation_acc: 45.556
#
# ---
# Epoch: 20
# learning_rate: 0.01
# Trainning Accuracy: 71.5246124268
# validation_acc: 44.748
#
# ---
# Epoch: 21
# learning_rate: 0.01
# Trainning Accuracy: 72.1655197144
# validation_acc: 44.636
#
# ---
# Epoch: 22
# learning_rate: 0.01
# Trainning Accuracy: 72.5521621704
# validation_acc: 42.073
#
# ---
# Epoch: 23
# learning_rate: 0.01
# Trainning Accuracy: 73.7782592773
# validation_acc: 47.924
#
# ---
# Epoch: 24
# learning_rate: 0.01
# Trainning Accuracy: 74.4052352905
# validation_acc: 44.553
#
# ---
# Epoch: 25
# learning_rate: 0.01
# Trainning Accuracy: 74.9764862061
# validation_acc: 44.079
#
# ---
# Epoch: 26
# learning_rate: 0.01
# Trainning Accuracy: 75.1959304810
# validation_acc: 37.977
#
# ---
# Epoch: 27
# learning_rate: 0.01
# Trainning Accuracy: 75.9831390381
# validation_acc: 44.553
#
# ---
# Epoch: 28
# learning_rate: 0.01
# Trainning Accuracy: 75.9692077637
# validation_acc: 37.308
#
# ---
# Epoch: 29
# learning_rate: 0.01
# Trainning Accuracy: 76.6588897705
# validation_acc: 39.203
#
# ---
# Epoch: 30
# learning_rate: 0.01
# Trainning Accuracy: 77.2858657837
# validation_acc: 42.324
#
# ---
# Epoch: 31
# learning_rate: 0.01
# Trainning Accuracy: 78.0277938843
# validation_acc: 37.476
#
# ---
# Epoch: 32
# learning_rate: 0.01
# Trainning Accuracy: 78.1601562500
# validation_acc: 45.584
#
# ---
# Epoch: 33
# learning_rate: 0.01
# Trainning Accuracy: 78.8637695312
# validation_acc: 45.305
#
# ---
# Epoch: 34
# learning_rate: 0.01
# Trainning Accuracy: 79.0692825317
# validation_acc: 40.318
#
# ---
# Epoch: 35
# learning_rate: 0.01
# Trainning Accuracy: 79.5151367188
# validation_acc: 46.754
#
# ---
# Epoch: 36
# learning_rate: 0.01
# Trainning Accuracy: 80.1037979126
# validation_acc: 50.098
#
# ---
# Epoch: 37
# learning_rate: 0.01
# Trainning Accuracy: 80.8004455566
# validation_acc: 43.717
#
# ---
# Epoch: 38
# learning_rate: 0.01
# Trainning Accuracy: 81.2602310181
# validation_acc: 45.082
#
# ---
# Epoch: 39
# learning_rate: 0.01
# Trainning Accuracy: 81.2602310181
# validation_acc: 44.274
#
# ---
# Epoch: 40
# learning_rate: 0.01
# Trainning Accuracy: 81.9777755737
# validation_acc: 50.878
# Saving..
# best_validation_acc: 50.878
#
# ---
# Epoch: 41
# learning_rate: 0.01
# Trainning Accuracy: 81.9742965698
# validation_acc: 49.791
#
# ---
# Epoch: 42
# learning_rate: 0.01
# Trainning Accuracy: 82.6291427612
# validation_acc: 44.581
#
# ---
# Epoch: 43
# learning_rate: 0.01
# Trainning Accuracy: 82.7963333130
# validation_acc: 51.964
# Saving..
# best_validation_acc: 51.964
#
# ---
# Epoch: 44
# learning_rate: 0.01
# Trainning Accuracy: 83.4233169556
# validation_acc: 43.884
#
# ---
# Epoch: 45
# learning_rate: 0.009000000000000001
# Trainning Accuracy: 84.1513137817
# validation_acc: 47.980
#
# ---
# Epoch: 46
# learning_rate: 0.009000000000000001
# Trainning Accuracy: 85.3007736206
# validation_acc: 41.934
#
# ---
# Epoch: 47
# learning_rate: 0.009000000000000001
# Trainning Accuracy: 85.3147125244
# validation_acc: 44.692
#
# ---
# Epoch: 48
# learning_rate: 0.009000000000000001
# Trainning Accuracy: 85.4157257080
# validation_acc: 40.011
#
# ---
# Epoch: 49
# learning_rate: 0.009000000000000001
# Trainning Accuracy: 85.8476409912
# validation_acc: 43.271
#
# ---
# Epoch: 50
# learning_rate: 0.008100000000000001
# Trainning Accuracy: 87.3767776489
# validation_acc: 41.126
#
# ---
# Epoch: 51
# learning_rate: 0.008100000000000001
# Trainning Accuracy: 88.0316314697
# validation_acc: 40.318
#
# ---
# Epoch: 52
# learning_rate: 0.008100000000000001
# Trainning Accuracy: 87.7042007446
# validation_acc: 40.596
#
# ---
# Epoch: 53
# learning_rate: 0.008100000000000001
# Trainning Accuracy: 88.2441024780
# validation_acc: 40.680
#
# ---
# Epoch: 54
# learning_rate: 0.008100000000000001
# Trainning Accuracy: 88.5192794800
# validation_acc: 43.383
#
# ---
# Epoch: 55
# learning_rate: 0.007290000000000001
# Trainning Accuracy: 89.5085144043
# validation_acc: 46.364
#
# ---
# Epoch: 56
# learning_rate: 0.007290000000000001
# Trainning Accuracy: 89.6826782227
# validation_acc: 42.240
#
# ---
# Epoch: 57
# learning_rate: 0.007290000000000001
# Trainning Accuracy: 90.1842651367
# validation_acc: 45.890
#
# ---
# Epoch: 58
# learning_rate: 0.007290000000000001
# Trainning Accuracy: 90.3166275024
# validation_acc: 46.893
#
# ---
# Epoch: 59
# learning_rate: 0.007290000000000001
# Trainning Accuracy: 90.7903442383
# validation_acc: 46.280
#
# ---
# Epoch: 60
# learning_rate: 0.006561
# Trainning Accuracy: 91.4242935181
# validation_acc: 39.760
#
# ---
# Epoch: 61
# learning_rate: 0.006561
# Trainning Accuracy: 91.7900314331
# validation_acc: 51.240
#
# ---
# Epoch: 62
# learning_rate: 0.006561
# Trainning Accuracy: 91.6402511597
# validation_acc: 42.770
#
# ---
# Epoch: 63
# learning_rate: 0.006561
# Trainning Accuracy: 92.2533035278
# validation_acc: 40.568
#
# ---
# Epoch: 64
# learning_rate: 0.006561
# Trainning Accuracy: 92.1557693481
# validation_acc: 39.593
#
# ---
# Epoch: 65
# learning_rate: 0.005904900000000001
# Trainning Accuracy: 93.2704010010
# validation_acc: 35.247
#
# ---
# Epoch: 66
# learning_rate: 0.005904900000000001
# Trainning Accuracy: 93.1693878174
# validation_acc: 35.665
#
# ---
# Epoch: 67
# learning_rate: 0.005904900000000001
# Trainning Accuracy: 93.2251205444
# validation_acc: 47.005
#
# ---
# Epoch: 68
# learning_rate: 0.005904900000000001
# Trainning Accuracy: 93.4584960938
# validation_acc: 41.321
#
# ---
# Epoch: 69
# learning_rate: 0.005904900000000001
# Trainning Accuracy: 93.7789535522
# validation_acc: 45.138
#
# ---
# Epoch: 70
# learning_rate: 0.00531441
# Trainning Accuracy: 94.3676223755
# validation_acc: 44.330
#
# ---
# Epoch: 71
# learning_rate: 0.00531441
# Trainning Accuracy: 94.4512176514
# validation_acc: 44.999
#
# ---
# Epoch: 72
# learning_rate: 0.00531441
# Trainning Accuracy: 94.8065032959
# validation_acc: 50.293
#
# ---
# Epoch: 73
# learning_rate: 0.00531441
# Trainning Accuracy: 94.8343734741
# validation_acc: 46.810
#
# ---
# Epoch: 74
# learning_rate: 0.00531441
# Trainning Accuracy: 94.6323471069
# validation_acc: 46.698
#
# ---
# Epoch: 75
# learning_rate: 0.004782969000000001
# Trainning Accuracy: 95.0782012939
# validation_acc: 41.711
#
# ---
# Epoch: 76
# learning_rate: 0.004782969000000001
# Trainning Accuracy: 95.6842803955
# validation_acc: 46.280
#
# ---
# Epoch: 77
# learning_rate: 0.004782969000000001
# Trainning Accuracy: 95.3882064819
# validation_acc: 43.912
#
# ---
# Epoch: 78
# learning_rate: 0.004782969000000001
# Trainning Accuracy: 95.4683227539
# validation_acc: 46.865
#
# ---
# Epoch: 79
# learning_rate: 0.004782969000000001
# Trainning Accuracy: 95.4300079346
# validation_acc: 44.525
#
# ---
# Epoch: 80
# learning_rate: 0.004304672100000001
# Trainning Accuracy: 96.2416000366
# validation_acc: 47.952
#
# ---
# Epoch: 81
# learning_rate: 0.004304672100000001
# Trainning Accuracy: 95.9838409424
# validation_acc: 44.274
#
# ---
# Epoch: 82
# learning_rate: 0.004304672100000001
# Trainning Accuracy: 96.3530578613
# validation_acc: 48.259
#
# ---
# Epoch: 83
# learning_rate: 0.004304672100000001
# Trainning Accuracy: 96.3112640381
# validation_acc: 44.218
#
# ---
# Epoch: 84
# learning_rate: 0.004304672100000001
# Trainning Accuracy: 96.4227218628
# validation_acc: 49.457
#
# ---
# Epoch: 85
# learning_rate: 0.003874204890000001
# Trainning Accuracy: 96.7153167725
# validation_acc: 48.732
#
# ---
# Epoch: 86
# learning_rate: 0.003874204890000001
# Trainning Accuracy: 96.7605972290
# validation_acc: 48.231
#
# ---
# Epoch: 87
# learning_rate: 0.003874204890000001
# Trainning Accuracy: 96.8650970459
# validation_acc: 48.704
#
# ---
# Epoch: 88
# learning_rate: 0.003874204890000001
# Trainning Accuracy: 96.7675628662
# validation_acc: 45.834
#
# ---
# Epoch: 89
# learning_rate: 0.003874204890000001
# Trainning Accuracy: 96.7989120483
# validation_acc: 48.008
#
# ---
# Epoch: 90
# learning_rate: 0.003486784401000001
# Trainning Accuracy: 97.1959991455
# validation_acc: 49.457
#
# ---
# Epoch: 91
# learning_rate: 0.003486784401000001
# Trainning Accuracy: 97.2830810547
# validation_acc: 49.317
#
# ---
# Epoch: 92
# learning_rate: 0.003486784401000001
# Trainning Accuracy: 97.6000595093
# validation_acc: 44.581
#
# ---
# Epoch: 93
# learning_rate: 0.003486784401000001
# Trainning Accuracy: 97.5408401489
# validation_acc: 45.305
#
# ---
# Epoch: 94
# learning_rate: 0.003486784401000001
# Trainning Accuracy: 97.3597106934
# validation_acc: 45.138
#
# ---
# Epoch: 95
# learning_rate: 0.0031381059609000006
# Trainning Accuracy: 97.6871337891
# validation_acc: 51.045
#
# ---
# Epoch: 96
# learning_rate: 0.0031381059609000006
# Trainning Accuracy: 97.5512924194
# validation_acc: 51.463
#
# ---
# Epoch: 97
# learning_rate: 0.0031381059609000006
# Trainning Accuracy: 97.7916336060
# validation_acc: 46.113
#
# ---
# Epoch: 98
# learning_rate: 0.0031381059609000006
# Trainning Accuracy: 97.9762420654
# validation_acc: 47.060
#
# ---
# Epoch: 99
# learning_rate: 0.0031381059609000006
# Trainning Accuracy: 98.0075912476
# validation_acc: 48.203
#
# ---
# Epoch: 100
# learning_rate: 0.0028242953648100013
# Trainning Accuracy: 97.9588317871
# validation_acc: 48.983
#
# ---
# Epoch: 101
# learning_rate: 0.0028242953648100013
# Trainning Accuracy: 97.8578109741
# validation_acc: 48.314
#
# ---
# Epoch: 102
# learning_rate: 0.0028242953648100013
# Trainning Accuracy: 97.9971466064
# validation_acc: 48.677
#
# ---
# Epoch: 103
# learning_rate: 0.0028242953648100013
# Trainning Accuracy: 98.0772552490
# validation_acc: 48.816
#
# ---
# Epoch: 104
# learning_rate: 0.0028242953648100013
# Trainning Accuracy: 98.0877075195
# validation_acc: 48.509
#
# ---
# Epoch: 105
# learning_rate: 0.002541865828329001
# Trainning Accuracy: 98.1538925171
# validation_acc: 51.184
#
# ---
# Epoch: 106
# learning_rate: 0.002541865828329001
# Trainning Accuracy: 98.2026519775
# validation_acc: 46.838
#
# ---
# Epoch: 107
# learning_rate: 0.002541865828329001
# Trainning Accuracy: 98.4046783447
# validation_acc: 49.930
#
# ---
# Epoch: 108
# learning_rate: 0.002541865828329001
# Trainning Accuracy: 98.4081649780
# validation_acc: 49.345
#
# ---
# Epoch: 109
# learning_rate: 0.002541865828329001
# Trainning Accuracy: 98.3872680664
# validation_acc: 47.729
#
# ---
# Epoch: 110
# learning_rate: 0.002287679245496101
# Trainning Accuracy: 98.4395141602
# validation_acc: 50.070
#
# ---
# Epoch: 111
# learning_rate: 0.002287679245496101
# Trainning Accuracy: 98.4499664307
# validation_acc: 50.794
#
# ---
# Epoch: 112
# learning_rate: 0.002287679245496101
# Trainning Accuracy: 98.5718765259
# validation_acc: 48.732
#
# ---
# Epoch: 113
# learning_rate: 0.002287679245496101
# Trainning Accuracy: 98.6554718018
# validation_acc: 47.896
#
# ---
# Epoch: 114
# learning_rate: 0.002287679245496101
# Trainning Accuracy: 98.6101913452
# validation_acc: 48.593
#
# ---
# Epoch: 115
# learning_rate: 0.002058911320946491
# Trainning Accuracy: 98.6241226196
# validation_acc: 50.376
#
# ---
# Epoch: 116
# learning_rate: 0.002058911320946491
# Trainning Accuracy: 98.6763763428
# validation_acc: 50.237
#
# ---
# Epoch: 117
# learning_rate: 0.002058911320946491
# Trainning Accuracy: 98.6067123413
# validation_acc: 49.122
#
# ---
# Epoch: 118
# learning_rate: 0.002058911320946491
# Trainning Accuracy: 98.6624374390
# validation_acc: 51.101
#
# ---
# Epoch: 119
# learning_rate: 0.002058911320946491
# Trainning Accuracy: 98.6728897095
# validation_acc: 49.345
#
# ---
# Epoch: 120
# learning_rate: 0.0018530201888518416
# Trainning Accuracy: 98.7146911621
# validation_acc: 49.401
#
# ---
# Epoch: 121
# learning_rate: 0.0018530201888518416
# Trainning Accuracy: 98.8017730713
# validation_acc: 48.621
#
# ---
# Epoch: 122
# learning_rate: 0.0018530201888518416
# Trainning Accuracy: 98.7599716187
# validation_acc: 48.398
#
# ---
# Epoch: 123
# learning_rate: 0.0018530201888518416
# Trainning Accuracy: 98.8400878906
# validation_acc: 50.432
#
# ---
# Epoch: 124
# learning_rate: 0.0018530201888518416
# Trainning Accuracy: 98.8087387085
# validation_acc: 50.766
#
# ---
# Epoch: 125
# learning_rate: 0.0016677181699666576
# Trainning Accuracy: 98.9828948975
# validation_acc: 48.064
#
# ---
# Epoch: 126
# learning_rate: 0.0016677181699666576
# Trainning Accuracy: 98.9097518921
# validation_acc: 51.686
#
# ---
# Epoch: 127
# learning_rate: 0.0016677181699666576
# Trainning Accuracy: 98.9445800781
# validation_acc: 48.788
#
# ---
# Epoch: 128
# learning_rate: 0.0016677181699666576
# Trainning Accuracy: 98.9619979858
# validation_acc: 51.797
#
# ---
# Epoch: 129
# learning_rate: 0.0016677181699666576
# Trainning Accuracy: 98.9167175293
# validation_acc: 50.293
#
# ---
# Epoch: 130
# learning_rate: 0.0015009463529699917
# Trainning Accuracy: 99.0595321655
# validation_acc: 52.744
# Saving..
# best_validation_acc: 52.744
#
# ---
# Epoch: 131
# learning_rate: 0.0015009463529699917
# Trainning Accuracy: 98.8992996216
# validation_acc: 52.466
#
# ---
# Epoch: 132
# learning_rate: 0.0015009463529699917
# Trainning Accuracy: 99.0455932617
# validation_acc: 50.961
#
# ---
# Epoch: 133
# learning_rate: 0.0015009463529699917
# Trainning Accuracy: 98.9132308960
# validation_acc: 51.017
#
# ---
# Epoch: 134
# learning_rate: 0.0015009463529699917
# Trainning Accuracy: 99.0560455322
# validation_acc: 48.537
#
# ---
# Epoch: 135
# learning_rate: 0.0013508517176729928
# Trainning Accuracy: 99.0281829834
# validation_acc: 50.543
#
# ---
# Epoch: 136
# learning_rate: 0.0013508517176729928
# Trainning Accuracy: 99.0351486206
# validation_acc: 47.701
#
# ---
# Epoch: 137
# learning_rate: 0.0013508517176729928
# Trainning Accuracy: 99.0281829834
# validation_acc: 52.549
#
# ---
# Epoch: 138
# learning_rate: 0.0013508517176729928
# Trainning Accuracy: 99.0908737183
# validation_acc: 49.847
#
# ---
# Epoch: 139
# learning_rate: 0.0013508517176729928
# Trainning Accuracy: 99.1570587158
# validation_acc: 51.240
#
# ---
# Epoch: 140
# learning_rate: 0.0012157665459056935
# Trainning Accuracy: 99.0943603516
# validation_acc: 53.413
# Saving..
# best_validation_acc: 53.413
#
# ---
# Epoch: 141
# learning_rate: 0.0012157665459056935
# Trainning Accuracy: 99.0037994385
# validation_acc: 48.704
#
# ---
# Epoch: 142
# learning_rate: 0.0012157665459056935
# Trainning Accuracy: 99.1500930786
# validation_acc: 49.652
#
# ---
# Epoch: 143
# learning_rate: 0.0012157665459056935
# Trainning Accuracy: 99.2127914429
# validation_acc: 51.686
#
# ---
# Epoch: 144
# learning_rate: 0.0012157665459056935
# Trainning Accuracy: 99.1431274414
# validation_acc: 52.577
#
# ---
# Epoch: 145
# learning_rate: 0.0010941898913151243
# Trainning Accuracy: 99.2232437134
# validation_acc: 51.602
#
# ---
# Epoch: 146
# learning_rate: 0.0010941898913151243
# Trainning Accuracy: 99.1326751709
# validation_acc: 52.549
#
# ---
# Epoch: 147
# learning_rate: 0.0010941898913151243
# Trainning Accuracy: 99.2476196289
# validation_acc: 48.008
#
# ---
# Epoch: 148
# learning_rate: 0.0010941898913151243
# Trainning Accuracy: 99.2023391724
# validation_acc: 51.017
#
# ---
# Epoch: 149
# learning_rate: 0.0010941898913151243
# Trainning Accuracy: 99.2232437134
# validation_acc: 51.686
#
# ---
# Epoch: 150
# learning_rate: 0.0009847709021836117
# Trainning Accuracy: 99.2406539917
# validation_acc: 51.658
#
# ---
# Epoch: 151
# learning_rate: 0.0009847709021836117
# Trainning Accuracy: 99.2267227173
# validation_acc: 51.630
#
# ---
# Epoch: 152
# learning_rate: 0.0009847709021836117
# Trainning Accuracy: 99.2302093506
# validation_acc: 52.243
#
# ---
# Epoch: 153
# learning_rate: 0.0009847709021836117
# Trainning Accuracy: 99.2963867188
# validation_acc: 51.519
#
# ---
# Epoch: 154
# learning_rate: 0.0009847709021836117
# Trainning Accuracy: 99.2929077148
# validation_acc: 52.048
#
# ---
# Epoch: 155
# learning_rate: 0.0008862938119652507
# Trainning Accuracy: 99.3033523560
# validation_acc: 51.463
#
# ---
# Epoch: 156
# learning_rate: 0.0008862938119652507
# Trainning Accuracy: 99.2963867188
# validation_acc: 53.831
# Saving..
# best_validation_acc: 53.831
#
# ---
# Epoch: 157
# learning_rate: 0.0008862938119652507
# Trainning Accuracy: 99.3068389893
# validation_acc: 49.819
#
# ---
# Epoch: 158
# learning_rate: 0.0008862938119652507
# Trainning Accuracy: 99.2720031738
# validation_acc: 51.128
#
# ---
# Epoch: 159
# learning_rate: 0.0008862938119652507
# Trainning Accuracy: 99.2929077148
# validation_acc: 51.491
#
# ---
# Epoch: 160
# learning_rate: 0.0007976644307687256
# Trainning Accuracy: 99.3381881714
# validation_acc: 51.964
#
# ---
# Epoch: 161
# learning_rate: 0.0007976644307687256
# Trainning Accuracy: 99.3138046265
# validation_acc: 54.388
# Saving..
# best_validation_acc: 54.388
#
# ---
# Epoch: 162
# learning_rate: 0.0007976644307687256
# Trainning Accuracy: 99.3695373535
# validation_acc: 53.525
#
# ---
# Epoch: 163
# learning_rate: 0.0007976644307687256
# Trainning Accuracy: 99.3347015381
# validation_acc: 55.336
# Saving..
# best_validation_acc: 55.336
#
# ---
# Epoch: 164
# learning_rate: 0.0007976644307687256
# Trainning Accuracy: 99.3834686279
# validation_acc: 52.382
#
# ---
# Epoch: 165
# learning_rate: 0.000717897987691853
# Trainning Accuracy: 99.3033523560
# validation_acc: 53.190
#
# ---
# Epoch: 166
# learning_rate: 0.000717897987691853
# Trainning Accuracy: 99.3242568970
# validation_acc: 51.017
#
# ---
# Epoch: 167
# learning_rate: 0.000717897987691853
# Trainning Accuracy: 99.3904342651
# validation_acc: 52.577
#
# ---
# Epoch: 168
# learning_rate: 0.000717897987691853
# Trainning Accuracy: 99.3590850830
# validation_acc: 53.720
#
# ---
# Epoch: 169
# learning_rate: 0.000717897987691853
# Trainning Accuracy: 99.3451538086
# validation_acc: 53.357
#
# ---
# Epoch: 170
# learning_rate: 0.0006461081889226677
# Trainning Accuracy: 99.3695373535
# validation_acc: 53.357
#
# ---
# Epoch: 171
# learning_rate: 0.0006461081889226677
# Trainning Accuracy: 99.3695373535
# validation_acc: 51.351
#
# ---
# Epoch: 172
# learning_rate: 0.0006461081889226677
# Trainning Accuracy: 99.4148178101
# validation_acc: 52.438
#
# ---
# Epoch: 173
# learning_rate: 0.0006461081889226677
# Trainning Accuracy: 99.3590850830
# validation_acc: 53.970
#
# ---
# Epoch: 174
# learning_rate: 0.0006461081889226677
# Trainning Accuracy: 99.3695373535
# validation_acc: 52.354
#
# ---
# Epoch: 175
# learning_rate: 0.000581497370030401
# Trainning Accuracy: 99.4461669922
# validation_acc: 54.305
#
# ---
# Epoch: 176
# learning_rate: 0.000581497370030401
# Trainning Accuracy: 99.3521194458
# validation_acc: 52.940
#
# ---
# Epoch: 177
# learning_rate: 0.000581497370030401
# Trainning Accuracy: 99.4357147217
# validation_acc: 53.274
#
# ---
# Epoch: 178
# learning_rate: 0.000581497370030401
# Trainning Accuracy: 99.4183044434
# validation_acc: 54.806
#
# ---
# Epoch: 179
# learning_rate: 0.000581497370030401
# Trainning Accuracy: 99.4183044434
# validation_acc: 52.522
#
# ---
# Epoch: 180
# learning_rate: 0.000523347633027361
# Trainning Accuracy: 99.3486328125
# validation_acc: 53.970
#
# ---
# Epoch: 181
# learning_rate: 0.000523347633027361
# Trainning Accuracy: 99.3312225342
# validation_acc: 53.079
#
# ---
# Epoch: 182
# learning_rate: 0.000523347633027361
# Trainning Accuracy: 99.4113311768
# validation_acc: 53.357
#
# ---
# Epoch: 183
# learning_rate: 0.000523347633027361
# Trainning Accuracy: 99.4113311768
# validation_acc: 54.138
#
# ---
# Epoch: 184
# learning_rate: 0.000523347633027361
# Trainning Accuracy: 99.4357147217
# validation_acc: 52.549
#
# ---
# Epoch: 185
# learning_rate: 0.0004710128697246249
# Trainning Accuracy: 99.4043655396
# validation_acc: 55.475
# Saving..
# best_validation_acc: 55.475
#
# ---
# Epoch: 186
# learning_rate: 0.0004710128697246249
# Trainning Accuracy: 99.4252700806
# validation_acc: 52.466
#
# ---
# Epoch: 187
# learning_rate: 0.0004710128697246249
# Trainning Accuracy: 99.4809951782
# validation_acc: 53.330
#
# ---
# Epoch: 188
# learning_rate: 0.0004710128697246249
# Trainning Accuracy: 99.4879684448
# validation_acc: 53.970
#
# ---
# Epoch: 189
# learning_rate: 0.0004710128697246249
# Trainning Accuracy: 99.4566192627
# validation_acc: 55.531
# Saving..
# best_validation_acc: 55.531
#
# ---
# Epoch: 190
# learning_rate: 0.0004239115827521624
# Trainning Accuracy: 99.4322357178
# validation_acc: 54.249
#
# ---
# Epoch: 191
# learning_rate: 0.0004239115827521624
# Trainning Accuracy: 99.4809951782
# validation_acc: 54.444
#
# ---
# Epoch: 192
# learning_rate: 0.0004239115827521624
# Trainning Accuracy: 99.4879684448
# validation_acc: 54.751
#
# ---
# Epoch: 193
# learning_rate: 0.0004239115827521624
# Trainning Accuracy: 99.5088653564
# validation_acc: 56.450
# Saving..
# best_validation_acc: 56.450
#
# ---
# Epoch: 194
# learning_rate: 0.0004239115827521624
# Trainning Accuracy: 99.4148178101
# validation_acc: 54.834
#
# ---
# Epoch: 195
# learning_rate: 0.00038152042447694615
# Trainning Accuracy: 99.5088653564
# validation_acc: 53.553
#
# ---
# Epoch: 196
# learning_rate: 0.00038152042447694615
# Trainning Accuracy: 99.4113311768
# validation_acc: 54.556
#
# ---
# Epoch: 197
# learning_rate: 0.00038152042447694615
# Trainning Accuracy: 99.5123443604
# validation_acc: 53.803
#
# ---
# Epoch: 198
# learning_rate: 0.00038152042447694615
# Trainning Accuracy: 99.4322357178
# validation_acc: 55.336
#
# ---
# Epoch: 199
# learning_rate: 0.00038152042447694615
# Trainning Accuracy: 99.4531326294
# validation_acc: 54.221
#
# ---
# Epoch: 200
# learning_rate: 0.00034336838202925153
# Trainning Accuracy: 99.4670639038
# validation_acc: 54.834
#
# ---
# Epoch: 201
# learning_rate: 0.00034336838202925153
# Trainning Accuracy: 99.5088653564
# validation_acc: 54.054
#
# ---
# Epoch: 202
# learning_rate: 0.00034336838202925153
# Trainning Accuracy: 99.5297622681
# validation_acc: 54.082
#
# ---
# Epoch: 203
# learning_rate: 0.00034336838202925153
# Trainning Accuracy: 99.5018997192
# validation_acc: 54.249
#
# ---
# Epoch: 204
# learning_rate: 0.00034336838202925153
# Trainning Accuracy: 99.4809951782
# validation_acc: 53.469
#
# ---
# Epoch: 205
# learning_rate: 0.00030903154382632634
# Trainning Accuracy: 99.5193176270
# validation_acc: 53.079
#
# ---
# Epoch: 206
# learning_rate: 0.00030903154382632634
# Trainning Accuracy: 99.4984130859
# validation_acc: 53.998
#
# ---
# Epoch: 207
# learning_rate: 0.00030903154382632634
# Trainning Accuracy: 99.4566192627
# validation_acc: 54.890
#
# ---
# Epoch: 208
# learning_rate: 0.00030903154382632634
# Trainning Accuracy: 99.4705505371
# validation_acc: 55.336
#
# ---
# Epoch: 209
# learning_rate: 0.00030903154382632634
# Trainning Accuracy: 99.5471801758
# validation_acc: 54.277
#
# ---
# Epoch: 210
# learning_rate: 0.00027812838944369376
# Trainning Accuracy: 99.5262832642
# validation_acc: 54.249
#
# ---
# Epoch: 211
# learning_rate: 0.00027812838944369376
# Trainning Accuracy: 99.5053787231
# validation_acc: 53.915
#
# ---
# Epoch: 212
# learning_rate: 0.00027812838944369376
# Trainning Accuracy: 99.4914474487
# validation_acc: 54.361
#
# ---
# Epoch: 213
# learning_rate: 0.00027812838944369376
# Trainning Accuracy: 99.5088653564
# validation_acc: 54.305
#
# ---
# Epoch: 214
# learning_rate: 0.00027812838944369376
# Trainning Accuracy: 99.5088653564
# validation_acc: 53.135
#
# ---
# Epoch: 215
# learning_rate: 0.0002503155504993244
# Trainning Accuracy: 99.5506668091
# validation_acc: 53.692
#
# ---
# Epoch: 216
# learning_rate: 0.0002503155504993244
# Trainning Accuracy: 99.5541458130
# validation_acc: 55.001
#
# ---
# Epoch: 217
# learning_rate: 0.0002503155504993244
# Trainning Accuracy: 99.5123443604
# validation_acc: 54.528
#
# ---
# Epoch: 218
# learning_rate: 0.0002503155504993244
# Trainning Accuracy: 99.5541458130
# validation_acc: 54.667
#
# ---
# Epoch: 219
# learning_rate: 0.0002503155504993244
# Trainning Accuracy: 99.5297622681
# validation_acc: 52.689
#
# ---
# Epoch: 220
# learning_rate: 0.00022528399544939195
# Trainning Accuracy: 99.5332489014
# validation_acc: 52.605
#
# ---
# Epoch: 221
# learning_rate: 0.00022528399544939195
# Trainning Accuracy: 99.5193176270
# validation_acc: 54.193
#
# ---
# Epoch: 222
# learning_rate: 0.00022528399544939195
# Trainning Accuracy: 99.5367279053
# validation_acc: 53.357
#
# ---
# Epoch: 223
# learning_rate: 0.00022528399544939195
# Trainning Accuracy: 99.5158309937
# validation_acc: 54.556
#
# ---
# Epoch: 224
# learning_rate: 0.00022528399544939195
# Trainning Accuracy: 99.5332489014
# validation_acc: 53.218
#
# ---
# Epoch: 225
# learning_rate: 0.00020275559590445276
# Trainning Accuracy: 99.4984130859
# validation_acc: 54.751
#
# ---
# Epoch: 226
# learning_rate: 0.00020275559590445276
# Trainning Accuracy: 99.5158309937
# validation_acc: 54.723
#
# ---
# Epoch: 227
# learning_rate: 0.00020275559590445276
# Trainning Accuracy: 99.5854949951
# validation_acc: 54.667
#
# ---
# Epoch: 228
# learning_rate: 0.00020275559590445276
# Trainning Accuracy: 99.5158309937
# validation_acc: 54.305
#
# ---
# Epoch: 229
# learning_rate: 0.00020275559590445276
# Trainning Accuracy: 99.5750427246
# validation_acc: 54.890
#
# ---
# Epoch: 230
# learning_rate: 0.0001824800363140075
# Trainning Accuracy: 99.5611114502
# validation_acc: 54.416
#
# ---
# Epoch: 231
# learning_rate: 0.0001824800363140075
# Trainning Accuracy: 99.4809951782
# validation_acc: 54.890
#
# ---
# Epoch: 232
# learning_rate: 0.0001824800363140075
# Trainning Accuracy: 99.5332489014
# validation_acc: 53.135
#
# ---
# Epoch: 233
# learning_rate: 0.0001824800363140075
# Trainning Accuracy: 99.5193176270
# validation_acc: 55.503
#
# ---
# Epoch: 234
# learning_rate: 0.0001824800363140075
# Trainning Accuracy: 99.5297622681
# validation_acc: 54.249
#
# ---
# Epoch: 235
# learning_rate: 0.00016423203268260675
# Trainning Accuracy: 99.6238098145
# validation_acc: 55.280
#
# ---
# Epoch: 236
# learning_rate: 0.00016423203268260675
# Trainning Accuracy: 99.5367279053
# validation_acc: 54.416
#
# ---
# Epoch: 237
# learning_rate: 0.00016423203268260675
# Trainning Accuracy: 99.5611114502
# validation_acc: 53.385
#
# ---
# Epoch: 238
# learning_rate: 0.00016423203268260675
# Trainning Accuracy: 99.5436935425
# validation_acc: 53.162
#
# ---
# Epoch: 239
# learning_rate: 0.00016423203268260675
# Trainning Accuracy: 99.5576324463
# validation_acc: 53.274
#
# ---
# Epoch: 240
# learning_rate: 0.00014780882941434607
# Trainning Accuracy: 99.6063919067
# validation_acc: 55.419
#
# ---
# Epoch: 241
# learning_rate: 0.00014780882941434607
# Trainning Accuracy: 99.5576324463
# validation_acc: 53.497
#
# ---
# Epoch: 242
# learning_rate: 0.00014780882941434607
# Trainning Accuracy: 99.5332489014
# validation_acc: 53.497
#
# ---
# Epoch: 243
# learning_rate: 0.00014780882941434607
# Trainning Accuracy: 99.5297622681
# validation_acc: 53.720
#
# ---
# Epoch: 244
# learning_rate: 0.00014780882941434607
# Trainning Accuracy: 99.5854949951
# validation_acc: 55.169
#
# ---
# Epoch: 245
# learning_rate: 0.00013302794647291146
# Trainning Accuracy: 99.5227966309
# validation_acc: 54.946
#
# ---
# Epoch: 246
# learning_rate: 0.00013302794647291146
# Trainning Accuracy: 99.5645980835
# validation_acc: 53.580
#
# ---
# Epoch: 247
# learning_rate: 0.00013302794647291146
# Trainning Accuracy: 99.5715637207
# validation_acc: 56.199
#
# ---
# Epoch: 248
# learning_rate: 0.00013302794647291146
# Trainning Accuracy: 99.5541458130
# validation_acc: 54.528
#
# ---
# Epoch: 249
# learning_rate: 0.00013302794647291146
# Trainning Accuracy: 99.5750427246
# validation_acc: 54.305
# best_validation_acc: 56.450
# best_validation_acc_epoch: 193

# %%
print(f"evaluating for dataset_model = {path}")

# load the best model according to validation
net.load_state_dict(torch.load(path + "/validation_model.t7")["net"])
net.eval()

test_loss = 0
correct = 0
total = 0
for batch_idx, (inputs, targets) in enumerate(testloader):
    bs, ncrops, c, h, w = np.shape(inputs)
    inputs = inputs.view(-1, c, h, w)
    if use_cuda:
        inputs, targets = inputs.cuda(), targets.cuda()
    with torch.no_grad():
        # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
        outputs = net(inputs)
        outputs_avg = outputs.view(bs, ncrops, -1).mean(1)  # avg over crops
        loss = criterion(outputs_avg, targets)
        test_loss += loss.data
        _, predicted = torch.max(outputs_avg.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()
  
print(f"Best model chosen based on best validation accuracy, ")
print(f"Achieved test accuracy {100. * correct / total}")
# Out:
# evaluating for dataset_model = FER2013_Xception
# Best model chosen based on best validation accuracy,
# Achieved test accuracy 56.95179748535156

# %%
max(1, 2)
# Out:
# 2
